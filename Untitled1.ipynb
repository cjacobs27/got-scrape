# %%
import requests
import pandas
import re
from bs4 import BeautifulSoup

r = requests.get("https://en.wikipedia.org/wiki/List_of_A_Song_of_Ice_and_Fire_characters")
c = r.content

soup = BeautifulSoup(c, "html.parser")
all = soup.find_all("span", {"class": "mw-headline"})
regex = ('(House|References|Secondary sources|Primary sources|Bibliography|External links|Other characters|Royal court and officials|Night\\\'s Watch and wildlings|The Sand Snakes)')
p = re.compile(regex)
namelist=[]
linklist = []
checklist = []
for item in all:
    name = item.text
    if p.match(name) is None:
        namelist.append(name)
        urlend = name.replace(" ", "_")
        url = str("https://en.wikipedia.org/wiki/" + urlend)
        linklist.append(url)
    else:
        pass

#character page exists checker - scrapes for redirect link text (this is the name of the character if redirected to
# the 'list of characters' page
a = 0
for b in linklist[a]:
    request = requests.get(linklist[a])
    z = request.content
    soup2 = BeautifulSoup(z, "html.parser")
    try:
        redirected = soup2.find("a", {"class:", "mw-redirect"}).text
        if type(redirected) == str:
                if redirected == namelist[a]:
                    checklist.append("None")
                elif redirected is None:
                    checklist.append("None")
                else:
                    checklist.append("Ok")
        elif type(redirected) != str:
            checklist.append("None")
    except:
        checklist.append("None")
    a = a + 1

print(namelist)
print(checklist)
# df = pandas.DataFrame(
#     {'Name': namelist,
#      'URL': linklist,
#      'Page': checklist})
# df.to_csv("data.csv")

# %%
import requests
import pandas
import re
from bs4 import BeautifulSoup

r = requests.get("https://en.wikipedia.org/wiki/List_of_A_Song_of_Ice_and_Fire_characters")
c = r.content

soup = BeautifulSoup(c, "html.parser")
all = soup.find_all("span", {"class": "mw-headline"})
regex = ('(House|References|Secondary sources|Primary sources|Bibliography|External links|Other characters|Royal court and officials|Night\\\'s Watch and wildlings|The Sand Snakes)')
p = re.compile(regex)
namelist=[]
linklist = []
checklist = []
for item in all:
    name = item.text
    if p.match(name) is None:
        namelist.append(name)
        if name == "Ned Stark":
            name = "Eddard Stark"
        else:
            pass
        urlend = name.replace(" ", "_")
        url = str("https://en.wikipedia.org/wiki/" + urlend)
        linklist.append(url)
    else:
        pass

#character page exists checker - scrapes for redirect link text (this is the name of the character if redirected to
# the 'list of characters' page
for item in linklist:
    a = 0
    while a != 50:
        request = requests.get(item)
        z = request.content
        soup2 = BeautifulSoup(z, "html.parser")
        try:
            redirected = soup2.find("a", {"class:", "mw-redirect"}).text
            if redirected == namelist[a]:
                # print("No")
                checklist.append("No")
            else:
                # print("Yes")
                checklist.append("Yes")
        except:
            # print("Fail")
            checklist.append("No")
        print(str(a) + " of 124 entries checked")
        a = a + 1
'''
Dataframe issue?
Look at this awesome page:

http://queirozf.com/entries/pandas-dataframe-by-example
'''

df = pandas.DataFrame(
    {'Name': namelist,
     'URL': linklist,
     'Page': checklist})
#this line sorts the rows with dedicated pages to the top of the list for testing
df.sort_values('Page',ascending=False)
# Out:
# 0 of 124 entries checked
# 1 of 124 entries checked
# 2 of 124 entries checked
# 3 of 124 entries checked
# 4 of 124 entries checked
# 5 of 124 entries checked
# 6 of 124 entries checked
# 7 of 124 entries checked
# 8 of 124 entries checked
# 9 of 124 entries checked
# 10 of 124 entries checked
# 11 of 124 entries checked
# 12 of 124 entries checked
# 13 of 124 entries checked
# 14 of 124 entries checked
# 15 of 124 entries checked
# 16 of 124 entries checked
# 17 of 124 entries checked
# 18 of 124 entries checked
# 19 of 124 entries checked
# 20 of 124 entries checked
# 21 of 124 entries checked
# 22 of 124 entries checked
# 23 of 124 entries checked
# 24 of 124 entries checked
# 25 of 124 entries checked
# 26 of 124 entries checked
# 27 of 124 entries checked
# 28 of 124 entries checked
# 29 of 124 entries checked
# 30 of 124 entries checked
# 31 of 124 entries checked
# 32 of 124 entries checked
# 33 of 124 entries checked
# 34 of 124 entries checked
# 35 of 124 entries checked
# 36 of 124 entries checked
# 37 of 124 entries checked
# 38 of 124 entries checked
# 39 of 124 entries checked
# 40 of 124 entries checked
# 41 of 124 entries checked
# 42 of 124 entries checked
# 43 of 124 entries checked
# 44 of 124 entries checked
# 45 of 124 entries checked
# 46 of 124 entries checked
# 47 of 124 entries checked
# 48 of 124 entries checked
# 49 of 124 entries checked
# 0 of 124 entries checked
# 1 of 124 entries checked
# 2 of 124 entries checked
# 3 of 124 entries checked
# 4 of 124 entries checked
# 5 of 124 entries checked
# 6 of 124 entries checked
# 7 of 124 entries checked
# 8 of 124 entries checked
# 9 of 124 entries checked
# 10 of 124 entries checked
# 11 of 124 entries checked
# 12 of 124 entries checked
# 13 of 124 entries checked
# 14 of 124 entries checked
# 15 of 124 entries checked
# 16 of 124 entries checked
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-517b8950ddcf> in <module>()
#      33     a = 0
#      34     while a != 50:
# ---> 35         request = requests.get(item)
#      36         z = request.content
#      37         soup2 = BeautifulSoup(z, "html.parser")
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     500         }
#     501         send_kwargs.update(settings)
# --> 502         resp = self.send(prep, **send_kwargs)
#     503
#     504         return resp
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     650
#     651         if not stream:
# --> 652             r.content
#     653
#     654         return r
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\requests\models.py in content(self)
#     823                 self._content = None
#     824             else:
# --> 825                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     826
#     827         self._content_consumed = True
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\requests\models.py in generate()
#     745             if hasattr(self.raw, 'stream'):
#     746                 try:
# --> 747                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     748                         yield chunk
#     749                 except ProtocolError as e:
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     434         else:
#     435             while not is_fp_closed(self._fp):
# --> 436                 data = self.read(amt=amt, decode_content=decode_content)
#     437
#     438                 if data:
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\http\client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\http\client.py in readinto(self, b)
#     486         # connection, and the user is reading more bytes than will be provided
#     487         # (for example, reading in 1k chunks)
# --> 488         n = self.fp.readinto(b)
#     489         if not n and b:
#     490             # Ideally, we would raise IncompleteRead if the content-length
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     935                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     936                   self.__class__)
# --> 937             return self.read(nbytes, buffer)
#     938         else:
#     939             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\ssl.py in read(self, len, buffer)
#     797             raise ValueError("Read on closed or unwrapped SSL socket.")
#     798         try:
# --> 799             return self._sslobj.read(len, buffer)
#     800         except SSLError as x:
#     801             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\users\chelsey\appdata\local\programs\python\python35\lib\ssl.py in read(self, len, buffer)
#     581         """
#     582         if buffer is not None:
# --> 583             v = self._sslobj.read(len, buffer)
#     584         else:
#     585             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
